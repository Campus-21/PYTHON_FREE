# %% [markdown]
# ## Операторы
#  --------------------------------------------------------------------
#
# | Действие       | Операция            | Пример |
# | ------------- |:------------------:| -----:|
# | Сложить     | +    | 2 + 2 |
# | Вычесть     | - |   4 - 1 |
# | Умножить     | * |   2 * 2 |
# | Разделить     | / |   4 / 2 |
# | Получить целую часть от деления     | // |   8 // 3 |
# | Получить остаток от деления     | % |   3 % 2 |
# | Возвести в степень  | **         |  2 ** 3  |
# |  Квадратный корень  | **0.5         |   4 ** 0.5 |
#
#  --------------------------------------------------------------------
#
#
# ## Примеры
#
# ### Задача 1
# ![1.png](attachment:1.png)
#
# ### Задача 2
# ![2.png](attachment:2.png)
#
# ### Задача 3
# ![3.png](attachment:3.png)
#
# ### Задача 4
# ![4.png](attachment:4.png)
#
# ### Задача 5
# ![5.png](attachment:5.png)

# %%
# Примеры 
## ============================================
# Найти x (67+33)/25 = x /(25-20)

print('Задача 1, x = ',(67+33)*(25-20)/25)

#==============================================
print('Задача 2', (4+5*60 - 17 + 65/4)**0.5)
print('Задача 3', 6.996 + 45*(13/2)**2+2*18**0.5)
print('Задача 4',(1267-20*(5**3/2)**2)/8**5*36**0.5)
print('Задача 5',(((((9**0.5)**3)**2)**2)/(-2)**(-3)))
# Out:
# Задача 1, x =  20.0
# Задача 2 17.414074767267998
# Задача 3 1916.7312813742387
# Задача 4 -14.0731201171875
# Задача 5 -4251528.0
